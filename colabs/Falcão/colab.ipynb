# %% [markdown]
# ### Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualização dos municípios do semiárido

# %%
# Lista dos municípios semiáridos
df_cities pd.read_csv('../../Dados/Municipios/lista-1262municipios-semiarido-2017.csv', sep=',')
df_municipios.head()
# Out:
#    id  Cod IBGE  UF    Município População Estimada - 2017
# 0   1   2700102  AL  ÁGUA BRANCA                     20467
# 1   2   2700300  AL    ARAPIRACA                    234185
# 2   3   2700706  AL      BATALHA                     18757
# 3   4   2700904  AL   BELO MONTE                      6797
# 4   5   2701209  AL  CACIMBINHAS                     10897

# %%
# Legenda com a sigla correspondente de cada coluna do dataset df_indices
df_legenda = pd.read_csv('../../Dados/Registros_Administrativos/dados_registros_administrativos_LEGENDA.csv', sep=',')
df_legenda.head(70)
# Out:
#             SIGLA                                  NOME DO INDICADOR
# 0      PMATPUB_EF  Percentual de matrículas da rede pública no en...  \
# 1      PMATPUB_EM  Percentual de matrículas da rede pública no en...
# 2      PMATPRI_EF  Percentual de matrículas da rede privada no en...
# 3      PMATPRI_EM  Percentual de matrículas da rede privada no en...
# 4   DIST_EF_TOTAL       Taxa de Distorção Idade-Série no fundamental
# ..            ...                                                ...
# 65   SNIS_PESGOTO  Percentual da população urbana residente em do...
# 66   SNIS_PESGTRA                       Percentual de esgoto tratado
# 67   SNIS_PCOLSEl                      Existência de coleta seletiva
# 68       SNIS_CDI  Percentual da população urbana atendida por se...
# 69         PFOCOS                    Concentração dos focos de calor
#
#                                             DEFINIÇÃO
# 0   Participação percentual das matrículas na rede...
# ...

# %%
df_indices = pd.read_csv('../../Dados/Registros_Administrativos/dados_registros_administrativos_total_2012_2027.csv', sep=',')
df_indices
# Out:
#         ANO DESAGREGACAO    IBGE7                        NOME  PMATPUB_EF
# 0      2013        TOTAL  1100015  Alta Floresta D&apos;Oeste       99.26  \
# 1      2013        TOTAL  1100023                   Ariquemes       91.12
# 2      2013        TOTAL  1100031                      Cabixi      100.00
# 3      2013        TOTAL  1100049                      Cacoal       85.55
# 4      2013        TOTAL  1100056                  Cerejeiras       97.18
# ...     ...          ...      ...                         ...         ...
# 27845  2017        TOTAL  5222005                  Vianópolis       94.55
# 27846  2017        TOTAL  5222054              Vicentinópolis      100.00
# 27847  2017        TOTAL  5222203                    Vila Boa      100.00
# 27848  2017        TOTAL  5222302               Vila Propício      100.00
# 27849  2017        TOTAL  5300108                    Brasília       73.62
#
#        PMATPUB_EM  PMATPRI_EF  PMATPRI_EM  DIST_EF_TOTAL  DIST_EM_TOTAL  ...
# ...
